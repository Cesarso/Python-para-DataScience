# %% [markdown]
# # Relatório de Análise VII

# %% [markdown]
# # Criando Agrupamentos

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0   1700.0       500.0  60.0     42.50          Casa
# 1   7000.0         0.0   0.0     70.00          Casa
# 2    800.0       390.0  20.0     53.33   Apartamento
# 3    800.0       230.0   0.0     16.67   Apartamento
# 4   1300.0       301.0  17.0     26.00   Apartamento
# 5  22000.0         0.0   0.0     29.33          Casa
# 6   1000.0         0.0   0.0     15.38          Casa
# 7   1500.0       642.0  74.0     21.43   Apartamento
# 8   1500.0       455.0  14.0     16.67   Apartamento
# 9   2000.0       561.0  50.0     50.00   Apartamento

# %%
dados['Valor'].mean()
# Out:
# 3960.0

# %%
# qiual o valor medio por bairro

# %%
#bairros = ['Barra da Tijuca', 'Copacabana', 'Jardim Botânico', 'Leblon', 'Ramos', 'Grajaú', 'Tijuca']

#selecao = dados['Bairro'].isin(bairros)

#dados = dados[selecao]

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0             Copacabana
# 1        Jardim Botânico
# 2                 Centro
# 3           Higienópolis
# 4               Cachambi
# 5        Barra da Tijuca
# 6                  Ramos
# 7                 Grajaú
# 8    Lins de Vasconcelos
# Name: Bairro, dtype: object

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
type(grupo_bairro)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grupo_bairro.groups
# Out:
# {'Barra da Tijuca': [5], 'Cachambi': [4], 'Centro': [2], 'Copacabana': [0, 9], 'Grajaú': [7], 'Higienópolis': [3], 'Jardim Botânico': [1], 'Lins de Vasconcelos': [8], 'Ramos': [6]}

# %%
for bairro, dados in grupo_bairro:
    print(bairro)
# Out:
# Barra da Tijuca
# Cachambi
# Centro
# Copacabana
# Grajaú
# Higienópolis
# Jardim Botânico
# Lins de Vasconcelos
# Ramos

# %%
 for bairro, dados in grupo_bairro:
    print(type(dados))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
 for bairro, data in grupo_bairro:
    print('{} -> {}'.format(bairro, data.Valor.mean())) # calculou a media pra cada bairro desse
# Out:
# Barra da Tijuca -> 22000.0
# Cachambi -> 1300.0
# Centro -> 800.0
# Copacabana -> 1850.0
# Grajaú -> 1500.0
# Higienópolis -> 800.0
# Jardim Botânico -> 7000.0
# Lins de Vasconcelos -> 1500.0
# Ramos -> 1000.0

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                        Valor  Condominio
# Bairro
# Barra da Tijuca      22000.0         0.0
# Cachambi              1300.0       301.0
# Centro                 800.0       390.0
# Copacabana            1850.0       530.5
# Grajaú                1500.0       642.0
# Higienópolis           800.0       230.0
# Jardim Botânico       7000.0         0.0
# Lins de Vasconcelos   1500.0       455.0
# Ramos                 1000.0         0.0

# %%
# Exercicio

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
sexo = alunos.groupby('Sexo')
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))
sexo.columns = ['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %% [markdown]
# # Estatisticas Descritivas

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                      count     mean     std      min      25%      50%  \
# Bairro
# Barra da Tijuca        1.0  22000.0     NaN  22000.0  22000.0  22000.0
# Cachambi               1.0   1300.0     NaN   1300.0   1300.0   1300.0
# Centro                 1.0    800.0     NaN    800.0    800.0    800.0
# Copacabana             2.0   1850.0  212.13   1700.0   1775.0   1850.0
# Grajaú                 1.0   1500.0     NaN   1500.0   1500.0   1500.0
# Higienópolis           1.0    800.0     NaN    800.0    800.0    800.0
# Jardim Botânico        1.0   7000.0     NaN   7000.0   7000.0   7000.0
# Lins de Vasconcelos    1.0   1500.0     NaN   1500.0   1500.0   1500.0
# Ramos                  1.0   1000.0     NaN   1000.0   1000.0   1000.0
#
#                          75%      max
# Bairro
# Barra da Tijuca      22000.0  22000.0
# Cachambi              1300.0   1300.0
# Centro                 800.0    800.0
# Copacabana            1925.0   2000.0
# Grajaú                1500.0   1500.0
# Higienópolis           800.0    800.0
# Jardim Botânico       7000.0   7000.0
# Lins de Vasconcelos   1500.0   1500.0
# Ramos                 1000.0   1000.0

# %%
# std é o desvio padrao.... min  de Minimo ....25% é 1° quartil...50% é a mediana....75% é o terceiro quartil

# %%
grupo_bairro['Valor'].aggregate(['min', 'max', 'sum']).rename(columns = {'min': 'Minimo', 'max': 'Maximo'})
# Out:
#                       Minimo   Maximo      sum
# Bairro
# Barra da Tijuca      22000.0  22000.0  22000.0
# Cachambi              1300.0   1300.0   1300.0
# Centro                 800.0    800.0    800.0
# Copacabana            1700.0   2000.0   3700.0
# Grajaú                1500.0   1500.0   1500.0
# Higienópolis           800.0    800.0    800.0
# Jardim Botânico       7000.0   7000.0   7000.0
# Lins de Vasconcelos   1500.0   1500.0   1500.0
# Ramos                 1000.0   1000.0   1000.0

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-a0d2faabd9e9> in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
conda install notebook ipykernel

# %%
ipython kernel install --user

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20, 10))

# %%
# A criação de grupamentos com o método groupby() facilita bastante na sumarização das informações de um DataFrame. 
# O método describe() aplicado a um grupamento gera um conjunto de estatísticas descritivas bastante útil no processo de 
# análise de dados, conforme o exemplo abaixo:

# %%
precos = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]], 
                        columns = ['Local', 'Produto', 'Preço'])
precos
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
produtos = precos.groupby('Produto')
produtos.describe().round(2)
# Out:
#         Preço
#         count  mean   std   min   25%   50%   75%  max
# Produto
# Batata    3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2
# Cebola    3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Tomate    3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0

# %%
estatisticas = ['mean', 'std', 'min', 'max']
nomes = {'mean': 'Média', 'std': 'Desvio Padrão','min': 'Mínimo', 'max': 'Máximo'}
produtos['Preço'].aggregate(estatisticas).rename(columns = nomes).round(2)
# Out:
#          Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Batata    3.96           0.26    3.69     4.2
# Cebola    2.06           0.41    1.69     2.5
# Tomate    3.43           0.52    2.99     4.0

# %%
produtos['Preço'].agg(['mean', 'std'])
# Out:
#              mean       std
# Produto
# Batata   3.960000  0.256320
# Cebola   2.060000  0.409512
# Tomate   3.426667  0.518684
